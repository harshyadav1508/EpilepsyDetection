# %%
# Import libraries and modules
import numpy as np
np.random.seed(123)  # for reproducibility
from sklearn.model_selection import StratifiedKFold
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU, Bidirectional
from keras.layers import Dropout
from keras.layers import Flatten, TimeDistributed, GlobalMaxPooling1D, GlobalAveragePooling1D
from keras.preprocessing import sequence
from keras.utils import np_utils
from keras import metrics
from keras import backend

# %%
df=pd.read_csv("/content/drive/My Drive/mtech_finalyr_project/modified_Dataset/final_csv_with_shuffle.csv",  index_col=[0])
print(df)


df["tag"] = df["tag"].subtract(1)
print(df)


df=df.drop(['4096'],axis=1)
df.columns
# Out:
#          0      1      2      3      4  ...   4093   4094   4095   4096  tag
# 0    -18.0  -55.0 -126.0 -202.0 -238.0  ... -224.0 -200.0 -127.0 -226.0    5
# 1    -26.0    1.0   29.0   41.0   33.0  ... -209.0 -207.0 -210.0 -107.0    5
# 2     68.0 -106.0 -149.0 -141.0 -109.0  ...  460.0  343.0  247.0 -468.0    5
# 3    343.0  311.0  284.0  274.0  260.0  ...  527.0  480.0  397.0  217.0    5
# 4    -63.0 -107.0 -208.0 -310.0 -395.0  ...   56.0   44.0  -37.0   28.0    5
# ..     ...    ...    ...    ...    ...  ...    ...    ...    ...    ...  ...
# 495  213.0  210.0  210.0  212.0  194.0  ...   -9.0   -2.0   20.0 -231.0    5
# 496   24.0   10.0   -9.0  -18.0   -9.0  ...  -39.0  -33.0  -28.0  -19.0    1
# 497  -20.0  -12.0   -6.0    6.0    8.0  ...   12.0    9.0    2.0  -14.0    1
# 498 -104.0 -100.0  -94.0  -87.0  -87.0  ...  -37.0  -45.0  -59.0  -53.0    3
# 499  -43.0  -57.0  -86.0 -106.0 -106.0  ...   39.0   21.0   -8.0  -43.0    3
#
# [500 rows x 4098 columns]
# ...

# %%
#two class problem A vs E
df_0_4=df
df_0_4=df_0_4.loc[(df_0_4.tag==0) | (df_0_4.tag==4) ]
df_0_4
df_0_4.to_csv("/content/drive/My Drive/mtech_finalyr_project/modified_Dataset/final_csv_with_shuffle_AvsE.csv",index=False)

# %%
#3 class problem AB vs CD vs E
df_01_23_4=df
df_01_23_4.tag=df_01_23_4.tag.replace({1:0, 3:2 }) 
df_01_23_4.to_csv("/content/drive/My Drive/mtech_finalyr_project/modified_Dataset/final_csv_with_shuffle_ABvsCDvsE.csv",index=False)
